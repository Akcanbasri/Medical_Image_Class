# %%
# import system libs 
import os
import time
import shutil
import itertools

# import data handling tools 
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt

# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from keras.models import Model, load_model, Sequential
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from keras.optimizers import Adam, Adamax
from keras import regularizers
from keras.metrics import categorical_crossentropy

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

# %%
cancer = pd.read_csv("./data/hmnist_28_28_RGB.csv")
df = cancer.copy()
df.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
y = df['label']
X = df.drop('label', axis=1)

# %%
from imblearn.over_sampling import RandomOverSampler 

oversample = RandomOverSampler()
Data, Label  = oversample.fit_resample(X, y)
Data = np.array(Data).reshape(-1, 28, 28, 3)
print('Shape of Data :', Data.shape)
# Out:
# Shape of Data : (46935, 28, 28, 3)

# %%
Label = np.array(Label)
Label
# Out:
# array([2, 2, 2, ..., 6, 6, 6], dtype=int64)

# %%
classes = {4: ('nv', ' melanocytic nevi'),
           6: ('mel', 'melanoma'),
           2 :('bkl', 'benign keratosis-like lesions'), 
           1:('bcc' , ' basal cell carcinoma'),
           5: ('vasc', ' pyogenic granulomas and hemorrhage'),
           0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(Data , Label , test_size = 0.25 , random_state = 49)

# %%
print(f'X_train shape: {X_train.shape}\nX_test shape: {X_test.shape}')
print(f'y_train shape: {y_train.shape}\ny_test shape: {y_test.shape}')
# Out:
# X_train shape: (35201, 28, 28, 3)
# X_test shape: (11734, 28, 28, 3)
# y_train shape: (35201,)
# y_test shape: (11734,)

# %%
from keras.utils.np_utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
datagen = ImageDataGenerator(rescale=(1./255)
                             ,rotation_range=10
                             ,zoom_range = 0.1
                             ,width_shift_range=0.1
                             ,height_shift_range=0.1)

testgen = ImageDataGenerator(rescale=(1./255))

# %%
from keras.callbacks import ReduceLROnPlateau

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy'
                                            , patience = 2
                                            , verbose=1
                                            ,factor=0.5
                                            , min_lr=0.00001)

# %%
model = keras.models.Sequential()

# Create Model Structure
model.add(keras.layers.Input(shape=[28, 28, 3]))
model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.MaxPooling2D())
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.MaxPooling2D())
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.MaxPooling2D())
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.MaxPooling2D())

model.add(keras.layers.Flatten())

model.add(keras.layers.Dropout(rate=0.2))
model.add(keras.layers.Dense(units=256, activation='relu', kernel_initializer='he_normal'))
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Dense(units=128, activation='relu', kernel_initializer='he_normal'))
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Dense(units=64, activation='relu', kernel_initializer='he_normal'))
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Dense(units=32, activation='relu', kernel_initializer='he_normal', kernel_regularizer=keras.regularizers.L1L2()))
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Dense(units=7, activation='softmax', kernel_initializer='glorot_uniform', name='classifier'))

model.compile(Adamax(learning_rate= 0.001), loss= 'categorical_crossentropy', metrics= ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  batch_normalization (BatchN  (None, 14, 14, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 64)        18496
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 7, 7, 64)         256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 7, 7, 128)         73856
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 128)         147584
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 3, 3, 128)        512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 256)         295168
#
#  conv2d_6 (Conv2D)           (None, 3, 3, 256)         590080
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 256)               65792
#
#  batch_normalization_3 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  batch_normalization_4 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  batch_normalization_5 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  batch_normalization_6 (Batc  (None, 32)               128
#  hNormalization)
#
#  classifier (Dense)          (None, 7)                 231
#
# =================================================================
# Total params: 1,275,079
# Trainable params: 1,273,671
# Non-trainable params: 1,408
# _________________________________________________________________

# %%
history = model.fit(X_train ,
                    y_train ,
                    epochs=25 ,
                    batch_size=128,
                    validation_data=(X_test , y_test) ,
                    callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/25
# 276/276 [==============================] - 82s 289ms/step - loss: 1.2077 - accuracy: 0.5696 - val_loss: 0.9374 - val_accuracy: 0.6569 - lr: 0.0010
# Epoch 2/25
# 276/276 [==============================] - 77s 281ms/step - loss: 0.4953 - accuracy: 0.8353 - val_loss: 0.3329 - val_accuracy: 0.8913 - lr: 0.0010
# Epoch 3/25
# 276/276 [==============================] - 77s 280ms/step - loss: 0.2813 - accuracy: 0.9076 - val_loss: 0.2148 - val_accuracy: 0.9265 - lr: 0.0010
# Epoch 4/25
# 276/276 [==============================] - 80s 290ms/step - loss: 0.1914 - accuracy: 0.9362 - val_loss: 0.1749 - val_accuracy: 0.9395 - lr: 0.0010
# Epoch 5/25
# 276/276 [==============================] - 83s 302ms/step - loss: 0.1372 - accuracy: 0.9543 - val_loss: 0.1656 - val_accuracy: 0.9457 - lr: 0.0010
# Epoch 6/25
# 276/276 [==============================] - 79s 286ms/step - loss: 0.1018 - accuracy: 0.9664 - val_loss: 0.1448 - val_accuracy: 0.9489 - lr: 0.0010
# Epoch 7/25
# 276/276 [==============================] - 77s 280ms/step - loss: 0.0848 - accuracy: 0.9725 - val_loss: 0.2896 - val_accuracy: 0.9116 - lr: 0.0010
# Epoch 8/25
# 276/276 [==============================] - 67s 245ms/step - loss: 0.0568 - accuracy: 0.9809 - val_loss: 0.1005 - val_accuracy: 0.9720 - lr: 0.0010
# Epoch 9/25
# 276/276 [==============================] - 68s 246ms/step - loss: 0.0500 - accuracy: 0.9831 - val_loss: 0.1241 - val_accuracy: 0.9559 - lr: 0.0010
# Epoch 10/25
# 275/276 [============================>.] - ETA: 0s - loss: 0.0464 - accuracy: 0.9850
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 276/276 [==============================] - 68s 246ms/step - loss: 0.0464 - accuracy: 0.9850 - val_loss: 0.1636 - val_accuracy: 0.9551 - lr: 0.0010
# Epoch 11/25
# 276/276 [==============================] - 69s 249ms/step - loss: 0.0208 - accuracy: 0.9932 - val_loss: 0.0528 - val_accuracy: 0.9853 - lr: 5.0000e-04
# Epoch 12/25
# 276/276 [==============================] - 68s 246ms/step - loss: 0.0077 - accuracy: 0.9983 - val_loss: 0.0649 - val_accuracy: 0.9839 - lr: 5.0000e-04
# Epoch 13/25
# 276/276 [==============================] - 68s 246ms/step - loss: 0.0075 - accuracy: 0.9979 - val_loss: 0.0540 - val_accuracy: 0.9868 - lr: 5.0000e-04
# Epoch 14/25
# 276/276 [==============================] - 68s 245ms/step - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.0611 - val_accuracy: 0.9845 - lr: 5.0000e-04
# Epoch 15/25
# 275/276 [============================>.] - ETA: 0s - loss: 0.0042 - accuracy: 0.9991
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 276/276 [==============================] - 68s 245ms/step - loss: 0.0043 - accuracy: 0.9990 - val_loss: 0.0940 - val_accuracy: 0.9798 - lr: 5.0000e-04
# Epoch 16/25
# 276/276 [==============================] - 84s 304ms/step - loss: 0.0035 - accuracy: 0.9993 - val_loss: 0.0537 - val_accuracy: 0.9862 - lr: 2.5000e-04
# Epoch 17/25
# 275/276 [============================>.] - ETA: 0s - loss: 0.0027 - accuracy: 0.9993
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 276/276 [==============================] - 85s 306ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.0602 - val_accuracy: 0.9865 - lr: 2.5000e-04
# Epoch 18/25
# 276/276 [==============================] - 70s 255ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0569 - val_accuracy: 0.9866 - lr: 1.2500e-04
# Epoch 19/25
# 275/276 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9998
# Epoch 19: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 276/276 [==============================] - 70s 255ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0572 - val_accuracy: 0.9862 - lr: 1.2500e-04
# Epoch 20/25
# 276/276 [==============================] - 70s 254ms/step - loss: 0.0013 - accuracy: 0.9999 - val_loss: 0.0540 - val_accuracy: 0.9873 - lr: 6.2500e-05
# Epoch 21/25
# 276/276 [==============================] - 70s 256ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0548 - val_accuracy: 0.9871 - lr: 6.2500e-05
# Epoch 22/25
# 275/276 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9997
# Epoch 22: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 276/276 [==============================] - 70s 255ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0562 - val_accuracy: 0.9867 - lr: 6.2500e-05
# Epoch 23/25
# 276/276 [==============================] - 70s 255ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0566 - val_accuracy: 0.9864 - lr: 3.1250e-05
# Epoch 24/25
# 275/276 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9998
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 276/276 [==============================] - 71s 256ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.0604 - val_accuracy: 0.9859 - lr: 3.1250e-05
# Epoch 25/25
# 276/276 [==============================] - 74s 267ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0578 - val_accuracy: 0.9862 - lr: 1.5625e-05

# %%
def plot_training(hist):
    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]

    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'
    
    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout
    plt.show()

# %%
plot_training(history)

# %%
train_score = model.evaluate(X_train, y_train, verbose= 1)
test_score = model.evaluate(X_test, y_test, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 1101/1101 [==============================] - 35s 32ms/step - loss: 0.0022 - accuracy: 0.9998
# 367/367 [==============================] - 11s 30ms/step - loss: 0.0578 - accuracy: 0.9862
# Train Loss:  0.0021982742473483086
# Train Accuracy:  0.9997727274894714
# --------------------
# Test Loss:  0.05779755860567093
# Test Accuracy:  0.9861939549446106

# %%
y_true = np.array(y_test)
y_pred = model.predict(X_test)

y_pred = np.argmax(y_pred , axis=1)
y_true = np.argmax(y_true , axis=1)
# Out:
# 367/367 [==============================] - 11s 29ms/step

# %%
classes_labels = []
for key in classes.keys():
    classes_labels.append(key)

print(classes_labels)
# Out:
# [4, 6, 2, 1, 5, 0, 3]

# %%
# Confusion matrix
cm = cm = confusion_matrix(y_true, y_pred, labels=classes_labels)

plt.figure(figsize= (10, 10))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

# %%
#Save the model
model.save('Skin Cancer.h5')

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model) 
tflite_model = converter.convert() 

print("model converted")

# Save the model. 
with open('Skin.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 7). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\WINDOWS\TEMP\tmpeikp_n5l\assets
# INFO:tensorflow:Assets written to: C:\WINDOWS\TEMP\tmpeikp_n5l\assets
# model converted
